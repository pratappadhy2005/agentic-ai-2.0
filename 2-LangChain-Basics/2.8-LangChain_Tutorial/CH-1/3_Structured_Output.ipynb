# %% [markdown]
# # ***Guiding in Prompts***

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_openai import ChatOpenAI
import os

from dotenv import load_dotenv

load_dotenv()  # This loads the variables from .env
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

llm_openai = ChatOpenAI(model_name="gpt-5-mini", temperature=0, openai_api_key=os.environ.get("OPENAI_API_KEY"))
result = llm_openai.invoke("Bro, tell me a fun fact about gen Z. Generate the output in key-value format.")
print(result.content)
# Out:
# {"fun_fact":"Pew Research defines Gen Z as people born 1997–2012; they’re the first generation to grow up with smartphones and social media from early childhood, which profoundly shaped how they learn, socialize, and consume media."}

# %% [markdown]
# # Structured Output Using Pydantic
# #

# %%
from pydantic import BaseModel, Field

class llm_schema(BaseModel):
    setup: str = Field(description="The setup of the joke.")
    punchline: str = Field(description="The punchline of the joke.")

# %%
obj = llm_schema(setup="Some setup", punchline="some punchline.")

# %%
llm_structured = llm_openai.with_structured_output(llm_schema)

result =llm_structured.invoke("Bro, tell me a fun fact about gen Z.")   
print(result.setup)
print(result.punchline)
# Out:
# Gen Z is the first generation to grow up with smartphones, social media, and streaming from a very young age.
# So they can make a viral meme, start a side hustle, and teach their parents how to use filters — all before breakfast.
# /Users/pratappadhy/Documents/Projects/Python/Pratap_Agentic_AI/2-LangChain-Basics/2.8-LangChain_Tutorial/.venv/lib/python3.12/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='parsed', input_value=llm_schema(setup='Gen Z i... all before breakfast.'), input_type=llm_schema])
#   return self.__pydantic_serializer__.to_python(

# %% [markdown]
# # Using Type Dict

# %%
from typing import TypedDict

class llm_schema(TypedDict):
    setup: str = Field(description="The setup of the joke.")
    punchline: str = Field(description="The punchline of the joke.")
    

llm_structured_type_dict = llm_openai.with_structured_output(llm_schema)

result =llm_structured_type_dict.invoke("Bro, tell me a fun fact about gen Z.")   
print(result['setup'])
print(result['punchline'])
# Out:
# Gen Z (roughly mid-1990s to early 2010s) are the first generation to grow up with smartphones and social media as a normal part of childhood.
# That made them fluent in short-form, visual communication—memes and videos—so they often learn, shop, and start cultural trends on platforms like YouTube and TikTok.
