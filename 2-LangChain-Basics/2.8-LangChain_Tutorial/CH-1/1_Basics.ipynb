# %% [markdown]
# ***LLM CALL***

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()  # This loads the variables from .env

# The client automatically picks up the OPENAI_API_KEY environment variable
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY")) 

response = client.chat.completions.create(
    model="gpt-5-mini", # Use a current model, e.g., gpt-4 or gpt-3.5-turbo
    messages=[
        {"role": "system", "content": "Bro, tell me a fun fact."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Bro — fun fact: wombats poop in cube-shaped pellets so it doesn't roll away, which helps them mark territory. Their intestines actually shape the poop into cubes. Want another weird one?
