# %% [markdown]
# ***LLM CALL***

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()  # This loads the variables from .env

# The client automatically picks up the OPENAI_API_KEY environment variable
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY")) 

response = client.chat.completions.create(
    model="gpt-5-mini", # Use a current model, e.g., gpt-4 or gpt-3.5-turbo
    messages=[
        {"role": "system", "content": "Bro, tell me a fun fact."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Bro — fun fact: a group of flamingos is called a "flamboyance."
# Bonus: their pink color actually comes from pigments in the food they eat (like shrimp and algae). Want another weird one?

# %%
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model_name="gpt-5-mini", temperature=0, openai_api_key=os.environ.get("OPENAI_API_KEY"))

response = llm_openai.invoke("What is the capital of France?").content
print(response)
# Out:
# The capital of France is Paris.

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model(model="gpt-5-mini")

response = llm.invoke("What is the capital of France?")
print(response)
# Out:
# content='The capital of France is Paris.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 13, 'total_tokens': 93, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DC118GBErnYGHHJIIy3PgLCUTyNGp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c84e6-6824-72f0-be6c-b4813274f0dd-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 80, 'total_tokens': 93, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}
